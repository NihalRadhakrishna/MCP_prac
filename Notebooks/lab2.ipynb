# %%
from dotenv import load_dotenv
from agents import Agent, Runner, trace
from agents.mcp import MCPServerStdio
from IPython.display import display, Markdown

load_dotenv(override=True)
# Out:
# True

# %%
import functools
import subprocess
import agents.mcp.server

agents.mcp.server.stdio_client = functools.partial(agents.mcp.server.stdio_client, errlog=subprocess.DEVNULL)

# %%
import sys
from pathlib import Path

here = Path.cwd().resolve()
root = here if (here / "backend").is_dir() else here.parent
if str(root) not in sys.path:
    sys.path.insert(0, str(root))

from backend.accounts import Account
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 8
#       5 if str(root) not in sys.path:
#       6     sys.path.insert(0, str(root))
# ----> 8 from backend.accounts import Account
#
# File ~\Desktop\My Learnings\Agentic AI\MCP_prac\backend\accounts.py:5
#       3 from dotenv import load_dotenv
#       4 from datetime import datetime
# ----> 5 from .market import get_share_price
#       6 from .database import write_account, read_account, write_log
#       8 load_dotenv(override=True)
#
# ModuleNotFoundError: No module named 'backend.market'

# %%
account = Account.get("Ed")
account.reset()
account

# %%
account.buy_shares("AMZN", 3, "Because this bookstore website looks promising")

# %%
account.report()

# %%
account.list_transactions()

# %%
params = {
    "command": "uv",
    "args": ["run", "-m", "backend.accounts_server"],
    "cwd": str(root),
}
async with MCPServerStdio(params=params, client_session_timeout_seconds=30) as server:
    mcp_tools = await server.list_tools()

# %%
mcp_tools
